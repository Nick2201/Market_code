# %%
# streamlit run stream_test.py
import yfinance as yf
import streamlit as st
import datetime
import plotly.graph_objects as go
import plotly
import pandas as pd
import numpy as np
import requests_cache
session = requests_cache.CachedSession('yfinance.cache')
session.headers['User-agent'] = 'my-program/1.0'

# %%
def take_data(Company_tiker: str,date_of_buy='2021-04-28'):
    tickerSymbol = Company_tiker.upper()

    now_now = datetime.datetime.today()

    now_data = now_now.strftime('%Y-%m-%d')

    start_t = datetime.datetime.strptime(date_of_buy,"%Y-%m-%d")
    

    tickerData = yf.Ticker(tickerSymbol)

    tickerDf = tickerData.history(period='1d', start=start_t, end=now_data)

    return tickerDf

# %%
current_course = take_data('RUB=X').max()['Close']

# %%
def make_candle(df):
    fig = go.Figure(data=[go.Candlestick(x=df.index,
                                     open=df['Open'], high=df['High'],
                                     low=df['Low'], close=df['Close'])
                      ])
    return fig

# %%
def make_dict_from_company(basic_porfolio_dox: 'excel document'):
    dict_companies_data = {}
    for index,row in account.iterrows():
        dict_companies_data[row['tiker']] = take_data(row['tiker'],str(row['date_purchase'].strftime('%Y-%m-%d')))
        dict_companies_data[row['tiker']]['date'] = dict_companies_data[row['tiker']].index
    return dict_companies_data

# %%
from functools import reduce
def count_mean_measure_all_sec(dict_companies_data):
    ac = pd.DataFrame()
    frames_number = len(dict_companies_data)
    stock_measurets = ['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
    for measure in stock_measurets:
        ac[measure] = reduce(
            lambda x,y: dict_companies_data[x][measure]+dict_companies_data[y][measure] ,
        dict_companies_data.keys()
        )/frames_number
    return ac

# %%
account = pd.read_excel('my_account.xlsx')
account.date_purchase = pd.to_datetime(account.date_purchase, format="%m-%d-%Y")
account
# Out:
#   tiker  price_buy  lots_buy date_purchase
# 0  STRA         93       350    2021-04-28
# 1  TNDM         94       110    2021-04-28

# %%
def porfolio_result(account=account):
    dictionary_info = {}
    dictionary_info['value_in_usd'] = round(account.result.sum())
    dictionary_info['value_in_rub'] =round(account.result.sum())*73
    dictionary_info['buy_sum_total'] = account['sum'].sum()
    dictionary_info['percent'] = dictionary_info['value_in_usd']/dictionary_info['buy_sum_total']
    dictionary_info['percent_display'] = f'{round(dictionary_info["percent"]*100,2)}%'

    return dictionary_info

# %%
dict_companies_data = make_dict_from_company(account)

# %%
def current_account_state():
    account['sum'] = account['price_buy'] * account['lots_buy']
    account['now_price'] = list(map(now_price,account.tiker))
    account['now_sum'] = round(account['now_price']*account['lots_buy'],0)
    account['result'] = account['now_sum'] - account['sum']
    account['percentage'] = account['result']/account['sum']
    
    return porfolio_result()

# %%
current_account_state()
# Out:
# {'value_in_usd': -7409,
#  'value_in_rub': -540857,
#  'buy_sum_total': 42890,
#  'percent': -0.1727442294241082,
#  'percent_display': '-17.27%'}

# %%
weight_avg_portfolio_plot = make_candle(count_mean_measure_all_sec(dict_companies_data))
weight_avg_portfolio_plot
# Out:
# <div>                            <div id="9735e8f3-7efa-4c25-8be6-23c9cfad83e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9735e8f3-7efa-4c25-8be6-23c9cfad83e4")) {                    Plotly.newPlot(                        "9735e8f3-7efa-4c25-8be6-23c9cfad83e4",                        [{"close":[87.52967071533203,88.7020149230957,85.42370986938477,82.8876953125,83.9177017211914,83.80844116210938,81.90885925292969,80.37709426879883,80.11494064331055,79.22010803222656,78.68910217285156,78.40689849853516,76.9189453125,77.15046691894531,77.13278198242188,78.42688369750977,78.35417175292969,79.87657165527344,79.33526992797852,78.66532135009766,77.76221466064453,78.14811325073242,79.88710021972656,77.84197616577148,78.46203231811523,78.747314453125,79.18519592285156,79.20892333984375,80.61722946166992,80.98095321655273,81.52336120605469,84.45872497558594,85.49383544921875,85.19307327270508,84.4483413696289,85.77587890625,86.03071975708008,85.78280639648438,87.27778244018555,85.82815933227539,86.61103820800781,88.13905334472656,88.8804931640625,87.32308959960938,87.72766876220703,86.43685913085938,87.07262420654297,87.08651351928711,87.94216918945312,86.6440658569336,84.81901168823242,84.83380508422852,84.19388580322266,83.24215698242188,82.50727462768555,82.60540008544922,84.31755447387695,83.51744079589844,85.8900146484375,85.70497512817383,86.94170761108398,87.14208984375,86.33190155029297,86.88146591186523,90.98426818847656,92.51047897338867,93.67441177368164,92.48568344116211,91.6905288696289,91.4424934387207,94.16564559936523,91.34654998779297,91.6711654663086,89.13028717041016,88.54394149780273,90.33448028564453,91.45608901977539,91.71552276611328,92.82617950439453,92.19295883178711,92.02219009399414,94.1711654663086,93.9723129272461,94.86011505126953,94.03754043579102,93.1884765625,93.31358337402344,94.81461715698242,94.92330169677734,95.82999801635742,95.44499969482422,95.76499938964844,103.28999710083008,103.29999923706055,101.67000198364258,99.05500030517578,96.69499969482422,97.7599983215332,97.45500183105469,97.21500015258789,96.65999984741211,96.44499969482422,96.6349983215332,96.93000030517578,98.41999816894531,97.82499694824219,96.95000076293945,94.6150016784668,95.79999923706055,94.93999862670898,96.56499862670898,95.54999923706055,97.01000213623047,97.56000137329102,99.2400016784668,99.77999877929688,98.75000381469727,99.86999893188477,100.86499786376953,102.2750015258789,98.29999923706055,96.27000045776367,99.04499816894531,99.02000045776367,99.625,99.1349983215332,100.5099983215332,100.56000137329102,99.68999862670898,101.83000183105469,102.27000045776367,104.10000228881836,103.3699951171875,105.70500183105469,98.56999588012695,97.44499588012695,98.7599983215332,98.39999771118164,96.56000137329102,97.20499992370605,98.88500022888184,98.99500274658203,101.47000312805176,100.86500358581543,97.3899974822998,98.2650032043457,96.09500122070312,94.84499931335449,96.24500274658203],"high":[89.90715949253558,89.44641228283268,89.33373267543558,85.98289670159605,84.78607701396851,84.51236415829419,84.76694651941028,84.6687327753852,83.60502761280603,81.00665961748456,79.94644727399398,79.52290274904658,79.7762396436278,78.64278928183177,77.9884424939942,79.89713178532264,78.67696302517203,80.30675948896102,81.58778191770563,80.14932580278207,79.26940188977392,78.93848539250533,80.23017059073177,80.84756622729154,79.70537399403011,80.32529909809367,79.74461918233692,80.15407196283434,81.70945197239965,81.73444737853615,83.72968970260517,84.85311258129778,85.69094836929,86.21825449913476,85.85137456118463,86.81998145490459,86.9005645223766,86.74587952134257,87.68432014495184,87.87828123594446,87.42245253128795,89.40370588101841,90.29620416474376,89.57390596137967,88.5139312188386,88.08 ...

# %%
fig_one_company = make_candle(take_data('tndm'))
plotly.offline.iplot(fig, filename='filename.png')
# Out:
# <div>                            <div id="285036ae-c319-47e1-b811-1fcf02aa832e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("285036ae-c319-47e1-b811-1fcf02aa832e")) {                    Plotly.newPlot(                        "285036ae-c319-47e1-b811-1fcf02aa832e",                        [{"close":[94.56999969482422,95.95999908447266,93.9800033569336,91.9000015258789,92.08999633789062,91.33999633789062,88.83999633789062,86.18000030517578,84.13999938964844,80.5,80.55999755859375,79.72000122070312,77.0,78.9000015258789,78.52999877929688,81.62999725341797,81.7699966430664,84.48999786376953,85.73999786376953,85.02999877929688,83.45999908447266,83.72000122070312,85.6500015258789,85.38999938964844,84.06999969482422,86.0,86.33000183105469,86.05000305175781,88.43000030517578,88.83000183105469,87.95999908447266,91.3499984741211,92.16000366210938,92.6500015258789,91.2300033569336,93.25,93.72000122070312,93.76000213623047,94.16999816894531,95.2300033569336,96.25,96.22000122070312,99.36000061035156,99.48999786376953,100.19000244140625,97.4000015258789,97.58000183105469,98.61000061035156,100.48999786376953,99.66999816894531,98.58000183105469,97.2699966430664,96.01000213623047,94.94999694824219,93.51000213623047,94.51000213623047,98.48999786376953,96.86000061035156,100.9800033569336,100.5999984741211,103.5199966430664,104.0199966430664,102.3499984741211,102.05000305175781,104.54000091552734,105.33000183105469,108.66999816894531,106.62000274658203,104.98999786376953,105.0,109.97000122070312,107.13999938964844,107.69000244140625,103.66999816894531,102.1500015258789,105.87000274658203,107.23999786376953,108.9000015258789,111.29000091552734,111.7699966430664,111.2300033569336,112.69000244140625,111.30000305175781,112.51000213623047,111.48999786376953,111.31999969482422,110.30999755859375,112.29000091552734,112.16999816894531,114.41999816894531,113.48999786376953,114.27999877929688,129.39999389648438,127.75,125.54000091552734,122.66000366210938,119.93000030517578,121.87999725341797,123.36000061035156,123.0999984741211,122.43000030517578,122.16999816894531,123.48999786376953,124.02999877929688,125.48999786376953,123.7699966430664,121.1500015258789,117.72000122070312,119.91999816894531,119.37999725341797,121.18000030517578,118.18000030517578,121.7300033569336,123.16000366210938,126.26000213623047,127.75,128.32000732421875,130.36000061035156,132.77999877929688,134.3000030517578,125.3499984741211,122.76000213623047,127.05999755859375,127.37000274658203,127.4000015258789,127.18000030517578,129.27999877929688,130.69000244140625,130.13999938964844,133.91000366210938,136.3300018310547,136.72000122070312,139.2899932861328,141.41000366210938,132.50999450683594,130.64999389648438,135.6699981689453,135.14999389648438,132.22000122070312,134.02999877929688,136.47000122070312,137.4600067138672,142.3800048828125,142.49000549316406,136.97999572753906,138.8800048828125,132.8000030517578,130.63999938964844,132.8800048828125],"high":[95.2699966430664,96.75,96.19000244140625,93.75,93.0,91.98999786376953,93.06999969482422,93.72000122070312,89.26000213623047,83.95500183105469,82.12000274658203,80.83000183105469,81.12999725341797,79.68000030517578,79.69999694824219,82.7300033569336,82.13999938964844,84.75,87.44000244140625,87.25,85.5,84.0999984741211,85.83999633789062,87.69000244140625,86.12999725341797,87.3499984741211,87.30000305175781,87.46399688720703,89.9000015258789,89.94999694824219,90.13999938964844,91.9800033569336,92.45500183105469,93.45999908447266,93.52999877929688,93.81999969482422,95.41999816894531,95.19000244140625,94.73500061035156,95.5,96.94999694824219,98.66000366210938,99.80000305175781,100.33999633789062,100.80000305175781,100.45999908447266,98.70999908447266,99.04000091552734,100.58499908447266,101.5500030517578 ...
